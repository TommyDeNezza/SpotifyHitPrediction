# %% [markdown]
# This file is used to scrape Spotify data from 2012 to 2022 and upload and save all that data into a csv for our modeling purposes.

# %%
# !pip install spotipy
# !pip install billboard.py
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting spotipy
#   Downloading spotipy-2.23.0-py3-none-any.whl (29 kB)
# Requirement already satisfied: six>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spotipy) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from spotipy) (1.26.15)
# Requirement already satisfied: requests>=2.25.0 in /usr/local/lib/python3.10/dist-packages (from spotipy) (2.27.1)
# Collecting redis>=3.5.3
#   Downloading redis-4.5.4-py3-none-any.whl (238 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.9/238.9 kB 10.5 MB/s eta 0:00:00
# Collecting async-timeout>=4.0.2
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->spotipy) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->spotipy) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->spotipy) (3.4)
# Installing collected packages: async-timeout, redis, spotipy
# Successfully installed async-timeout-4.0.2 redis-4.5.4 spotipy-2.23.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting billboard.py
#   Downloading billboard.py-7.0.0-py2.py3-none-any.whl (7.0 kB)
# Requirement already satisfied: requests>=2.2.1 in /usr/local/lib/python3.10/dist-packages (from billboard.py) (2.27.1)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from billboard.py) (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.4.1->billboard.py) (2.4.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.2.1->billboard.py) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.2.1->billboard.py) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.2.1->billboard.py) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.2.1->billboard.py) (2.0.12)
# Installing collected packages: billboard.py
# Successfully installed billboard.py-7.0.0

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import billboard
import datetime
cid = 'cid'
secret = 'secret'
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager
=
client_credentials_manager)

# %%
song_data = []


for i in range(0,1000,50):
  query = "year:2021-2022 genre:country"
  results = sp.search(q=query, type="track", limit=50, offset=i)
  tracks = results["tracks"]["items"]
  for track in tracks:
    name = track["name"][:track["name"].index(' [with')] if ' [with' in track["name"] else track["name"]
    name = name[:name.index(' [feat')] if ' [feat' in name else name
    name = name[:name.index(' (with')] if ' (with' in name else name
    name = name[:name.index(' (feat')] if ' (feat' in name else name
    artist = track["artists"][0]["name"]
    features = sp.audio_features(track["id"])[0]
    song_data += [{
        "name": name.upper(),
        "artist": artist.upper(),
        "danceability": features["danceability"],
        "energy": features["energy"],
        "key": features["key"],
        "loudness": features["loudness"],
        "mode": features["mode"],
        "speechiness": features["speechiness"],
        "acousticness": features["acousticness"],
        "instrumentalness": features["instrumentalness"],
        "liveness": features["liveness"],
        "valence": features["valence"],
        "tempo": features["tempo"],
        "duration_ms": features["duration_ms"]
    }]

songs_df = pd.DataFrame(song_data)

start_date = datetime.date(2021, 1, 1)
end_date = datetime.date(2022, 12, 31)

current_date = start_date
hit_songs = set()

while current_date <= end_date:
    chart = billboard.ChartData("country-songs", date=current_date)
    for song in chart:
      title = song.title
      artist = song.artist[:song.artist.index(" Featuring")]  if " Featuring" in song.artist else song.artist
      artist = artist[:artist.index(" &")]  if " &" in artist else artist
      artist = artist[:artist.index(",")]  if "," in artist else artist
      hit_songs.update([(title.upper(), artist.upper())])

    # print(current_date, hit_songs)
    # hit_songs.update([(song.title, song.artist[:song.artist.index(" Featuring")]  if " Featuring" in song.artist else song.artist) for song in chart])
    current_date += datetime.timedelta(weeks=1)
    # print(current_date, [(song.title, song.artist[:song.artist.index(" Featuring")]  if " Featuring" in song.artist else song.artist) for song in chart])

# Assign "hit" feature in the DataFrame
songs_df["hit"] = songs_df.apply(lambda row: 1 if (row["name"], row["artist"]) in hit_songs else 0, axis=1)

songs_df

from google.colab import drive
drive.mount('/content/drive')

songs_df.to_csv('SpotifyAPI_country21-22.csv')
# !cp SpotifyAPI_country21-22.csv "drive/My Drive/Spotify/"
# Out:
# Mounted at /content/drive

# %%
song_data = []


for i in range(0,1000,50):
  query = "year:2020-2021 genre:country"
  results = sp.search(q=query, type="track", limit=50, offset=i)
  tracks = results["tracks"]["items"]
  for track in tracks:
    name = track["name"][:track["name"].index(' [with')] if ' [with' in track["name"] else track["name"]
    name = name[:name.index(' [feat')] if ' [feat' in name else name
    name = name[:name.index(' (with')] if ' (with' in name else name
    name = name[:name.index(' (feat')] if ' (feat' in name else name
    artist = track["artists"][0]["name"]
    features = sp.audio_features(track["id"])[0]
    song_data += [{
        "name": name.upper(),
        "artist": artist.upper(),
        "danceability": features["danceability"],
        "energy": features["energy"],
        "key": features["key"],
        "loudness": features["loudness"],
        "mode": features["mode"],
        "speechiness": features["speechiness"],
        "acousticness": features["acousticness"],
        "instrumentalness": features["instrumentalness"],
        "liveness": features["liveness"],
        "valence": features["valence"],
        "tempo": features["tempo"],
        "duration_ms": features["duration_ms"]
    }]

songs_df = pd.DataFrame(song_data)

start_date = datetime.date(2020, 1, 1)
end_date = datetime.date(2021, 12, 31)

current_date = start_date
hit_songs = set()

while current_date <= end_date:
    chart = billboard.ChartData("country-songs", date=current_date)
    for song in chart:
      title = song.title
      artist = song.artist[:song.artist.index(" Featuring")]  if " Featuring" in song.artist else song.artist
      artist = artist[:artist.index(" &")]  if " &" in artist else artist
      artist = artist[:artist.index(",")]  if "," in artist else artist
      hit_songs.update([(title.upper(), artist.upper())])

    # print(current_date, hit_songs)
    # hit_songs.update([(song.title, song.artist[:song.artist.index(" Featuring")]  if " Featuring" in song.artist else song.artist) for song in chart])
    current_date += datetime.timedelta(weeks=1)
    # print(current_date, [(song.title, song.artist[:song.artist.index(" Featuring")]  if " Featuring" in song.artist else song.artist) for song in chart])

# Assign "hit" feature in the DataFrame
songs_df["hit"] = songs_df.apply(lambda row: 1 if (row["name"], row["artist"]) in hit_songs else 0, axis=1)

songs_df

from google.colab import drive
drive.mount('/content/drive')

songs_df.to_csv('SpotifyAPI_country20-21.csv')
# !cp SpotifyAPI_country20-21.csv "drive/My Drive/Spotify/"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
song_data = []


for i in range(0,1000,50):
  query = "year:2019-2020 genre:country"
  results = sp.search(q=query, type="track", limit=50, offset=i)
  tracks = results["tracks"]["items"]
  for track in tracks:
    name = track["name"][:track["name"].index(' [with')] if ' [with' in track["name"] else track["name"]
    name = name[:name.index(' [feat')] if ' [feat' in name else name
    name = name[:name.index(' (with')] if ' (with' in name else name
    name = name[:name.index(' (feat')] if ' (feat' in name else name
    artist = track["artists"][0]["name"]
    features = sp.audio_features(track["id"])[0]
    song_data += [{
        "name": name.upper(),
        "artist": artist.upper(),
        "danceability": features["danceability"],
        "energy": features["energy"],
        "key": features["key"],
        "loudness": features["loudness"],
        "mode": features["mode"],
        "speechiness": features["speechiness"],
        "acousticness": features["acousticness"],
        "instrumentalness": features["instrumentalness"],
        "liveness": features["liveness"],
        "valence": features["valence"],
        "tempo": features["tempo"],
        "duration_ms": features["duration_ms"]
    }]

songs_df = pd.DataFrame(song_data)

start_date = datetime.date(2019, 1, 1)
end_date = datetime.date(2020, 12, 31)

current_date = start_date
hit_songs = set()

while current_date <= end_date:
    chart = billboard.ChartData("country-songs", date=current_date)
    for song in chart:
      title = song.title
      artist = song.artist[:song.artist.index(" Featuring")]  if " Featuring" in song.artist else song.artist
      artist = artist[:artist.index(" &")]  if " &" in artist else artist
      artist = artist[:artist.index(",")]  if "," in artist else artist
      hit_songs.update([(title.upper(), artist.upper())])

    # print(current_date, hit_songs)
    # hit_songs.update([(song.title, song.artist[:song.artist.index(" Featuring")]  if " Featuring" in song.artist else song.artist) for song in chart])
    current_date += datetime.timedelta(weeks=1)
    # print(current_date, [(song.title, song.artist[:song.artist.index(" Featuring")]  if " Featuring" in song.artist else song.artist) for song in chart])

# Assign "hit" feature in the DataFrame
songs_df["hit"] = songs_df.apply(lambda row: 1 if (row["name"], row["artist"]) in hit_songs else 0, axis=1)

songs_df

from google.colab import drive
drive.mount('/content/drive')

songs_df.to_csv('SpotifyAPI_country19-20.csv')
# !cp SpotifyAPI_country19-20.csv "drive/My Drive/Spotify/"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
song_data = []


for i in range(0,1000,50):
  query = "year:2018-2019 genre:country"
  results = sp.search(q=query, type="track", limit=50, offset=i)
  tracks = results["tracks"]["items"]
  for track in tracks:
    name = track["name"][:track["name"].index(' [with')] if ' [with' in track["name"] else track["name"]
    name = name[:name.index(' [feat')] if ' [feat' in name else name
    name = name[:name.index(' (with')] if ' (with' in name else name
    name = name[:name.index(' (feat')] if ' (feat' in name else name
    artist = track["artists"][0]["name"]
    features = sp.audio_features(track["id"])[0]
    song_data += [{
        "name": name.upper(),
        "artist": artist.upper(),
        "danceability": features["danceability"],
        "energy": features["energy"],
        "key": features["key"],
        "loudness": features["loudness"],
        "mode": features["mode"],
        "speechiness": features["speechiness"],
        "acousticness": features["acousticness"],
        "instrumentalness": features["instrumentalness"],
        "liveness": features["liveness"],
        "valence": features["valence"],
        "tempo": features["tempo"],
        "duration_ms": features["duration_ms"]
    }]

songs_df = pd.DataFrame(song_data)

start_date = datetime.date(2018, 1, 1)
end_date = datetime.date(2019, 12, 31)

current_date = start_date
hit_songs = set()

while current_date <= end_date:
    chart = billboard.ChartData("country-songs", date=current_date)
    for song in chart:
      title = song.title
      artist = song.artist[:song.artist.index(" Featuring")]  if " Featuring" in song.artist else song.artist
      artist = artist[:artist.index(" &")]  if " &" in artist else artist
      artist = artist[:artist.index(",")]  if "," in artist else artist
      hit_songs.update([(title.upper(), artist.upper())])

    # print(current_date, hit_songs)
    # hit_songs.update([(song.title, song.artist[:song.artist.index(" Featuring")]  if " Featuring" in song.artist else song.artist) for song in chart])
    current_date += datetime.timedelta(weeks=1)
    # print(current_date, [(song.title, song.artist[:song.artist.index(" Featuring")]  if " Featuring" in song.artist else song.artist) for song in chart])

# Assign "hit" feature in the DataFrame
songs_df["hit"] = songs_df.apply(lambda row: 1 if (row["name"], row["artist"]) in hit_songs else 0, axis=1)

songs_df
from google.colab import drive
drive.mount('/content/drive')

songs_df.to_csv('SpotifyAPI_country18-19.csv')
# !cp SpotifyAPI_country18-19.csv "drive/My Drive/Spotify/"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
song_data = []


for i in range(0,1000,50):
  query = "year:2017-2018 genre:country"
  results = sp.search(q=query, type="track", limit=50, offset=i)
  tracks = results["tracks"]["items"]
  for track in tracks:
    name = track["name"][:track["name"].index(' [with')] if ' [with' in track["name"] else track["name"]
    name = name[:name.index(' [feat')] if ' [feat' in name else name
    name = name[:name.index(' (with')] if ' (with' in name else name
    name = name[:name.index(' (feat')] if ' (feat' in name else name
    artist = track["artists"][0]["name"]
    features = sp.audio_features(track["id"])[0]
    song_data += [{
        "name": name.upper(),
        "artist": artist.upper(),
        "danceability": features["danceability"],
        "energy": features["energy"],
        "key": features["key"],
        "loudness": features["loudness"],
        "mode": features["mode"],
        "speechiness": features["speechiness"],
        "acousticness": features["acousticness"],
        "instrumentalness": features["instrumentalness"],
        "liveness": features["liveness"],
        "valence": features["valence"],
        "tempo": features["tempo"],
        "duration_ms": features["duration_ms"]
    }]

songs_df = pd.DataFrame(song_data)

start_date = datetime.date(2017, 1, 1)
end_date = datetime.date(2018, 12, 31)

current_date = start_date
hit_songs = set()

while current_date <= end_date:
    chart = billboard.ChartData("country-songs", date=current_date)
    for song in chart:
      title = song.title
      artist = song.artist[:song.artist.index(" Featuring")]  if " Featuring" in song.artist else song.artist
      artist = artist[:artist.index(" &")]  if " &" in artist else artist
      artist = artist[:artist.index(",")]  if "," in artist else artist
      hit_songs.update([(title.upper(), artist.upper())])

    # print(current_date, hit_songs)
    # hit_songs.update([(song.title, song.artist[:song.artist.index(" Featuring")]  if " Featuring" in song.artist else song.artist) for song in chart])
    current_date += datetime.timedelta(weeks=1)
    # print(current_date, [(song.title, song.artist[:song.artist.index(" Featuring")]  if " Featuring" in song.artist else song.artist) for song in chart])

# Assign "hit" feature in the DataFrame
songs_df["hit"] = songs_df.apply(lambda row: 1 if (row["name"], row["artist"]) in hit_songs else 0, axis=1)

songs_df
from google.colab import drive
drive.mount('/content/drive')

songs_df.to_csv('SpotifyAPI_country17-18.csv')
# !cp SpotifyAPI_country17-18.csv "drive/My Drive/Spotify/"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
song_data = []


for i in range(0,1000,50):
  query = "year:2016-2017 genre:country"
  results = sp.search(q=query, type="track", limit=50, offset=i)
  tracks = results["tracks"]["items"]
  for track in tracks:
    name = track["name"][:track["name"].index(' [with')] if ' [with' in track["name"] else track["name"]
    name = name[:name.index(' [feat')] if ' [feat' in name else name
    name = name[:name.index(' (with')] if ' (with' in name else name
    name = name[:name.index(' (feat')] if ' (feat' in name else name
    artist = track["artists"][0]["name"]
    features = sp.audio_features(track["id"])[0]
    song_data += [{
        "name": name.upper(),
        "artist": artist.upper(),
        "danceability": features["danceability"],
        "energy": features["energy"],
        "key": features["key"],
        "loudness": features["loudness"],
        "mode": features["mode"],
        "speechiness": features["speechiness"],
        "acousticness": features["acousticness"],
        "instrumentalness": features["instrumentalness"],
        "liveness": features["liveness"],
        "valence": features["valence"],
        "tempo": features["tempo"],
        "duration_ms": features["duration_ms"]
    }]

songs_df = pd.DataFrame(song_data)

start_date = datetime.date(2016, 1, 1)
end_date = datetime.date(2017, 12, 31)

current_date = start_date
hit_songs = set()

while current_date <= end_date:
    chart = billboard.ChartData("country-songs", date=current_date)
    for song in chart:
      title = song.title
      artist = song.artist[:song.artist.index(" Featuring")]  if " Featuring" in song.artist else song.artist
      artist = artist[:artist.index(" &")]  if " &" in artist else artist
      artist = artist[:artist.index(",")]  if "," in artist else artist
      hit_songs.update([(title.upper(), artist.upper())])

    # print(current_date, hit_songs)
    # hit_songs.update([(song.title, song.artist[:song.artist.index(" Featuring")]  if " Featuring" in song.artist else song.artist) for song in chart])
    current_date += datetime.timedelta(weeks=1)
    # print(current_date, [(song.title, song.artist[:song.artist.index(" Featuring")]  if " Featuring" in song.artist else song.artist) for song in chart])

# Assign "hit" feature in the DataFrame
songs_df["hit"] = songs_df.apply(lambda row: 1 if (row["name"], row["artist"]) in hit_songs else 0, axis=1)

songs_df

from google.colab import drive
drive.mount('/content/drive')

songs_df.to_csv('SpotifyAPI_country16-17.csv')
# !cp SpotifyAPI_country16-17.csv "drive/My Drive/Spotify/"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
song_data = []


for i in range(0,1000,50):
  query = "year:2015-2016 genre:country"
  results = sp.search(q=query, type="track", limit=50, offset=i)
  tracks = results["tracks"]["items"]
  for track in tracks:
    name = track["name"][:track["name"].index(' [with')] if ' [with' in track["name"] else track["name"]
    name = name[:name.index(' [feat')] if ' [feat' in name else name
    name = name[:name.index(' (with')] if ' (with' in name else name
    name = name[:name.index(' (feat')] if ' (feat' in name else name
    artist = track["artists"][0]["name"]
    features = sp.audio_features(track["id"])[0]
    song_data += [{
        "name": name.upper(),
        "artist": artist.upper(),
        "danceability": features["danceability"],
        "energy": features["energy"],
        "key": features["key"],
        "loudness": features["loudness"],
        "mode": features["mode"],
        "speechiness": features["speechiness"],
        "acousticness": features["acousticness"],
        "instrumentalness": features["instrumentalness"],
        "liveness": features["liveness"],
        "valence": features["valence"],
        "tempo": features["tempo"],
        "duration_ms": features["duration_ms"]
    }]

songs_df = pd.DataFrame(song_data)

start_date = datetime.date(2015, 1, 1)
end_date = datetime.date(2016, 12, 31)

current_date = start_date
hit_songs = set()

while current_date <= end_date:
    chart = billboard.ChartData("country-songs", date=current_date)
    for song in chart:
      title = song.title
      artist = song.artist[:song.artist.index(" Featuring")]  if " Featuring" in song.artist else song.artist
      artist = artist[:artist.index(" &")]  if " &" in artist else artist
      artist = artist[:artist.index(",")]  if "," in artist else artist
      hit_songs.update([(title.upper(), artist.upper())])

    # print(current_date, hit_songs)
    # hit_songs.update([(song.title, song.artist[:song.artist.index(" Featuring")]  if " Featuring" in song.artist else song.artist) for song in chart])
    current_date += datetime.timedelta(weeks=1)
    # print(current_date, [(song.title, song.artist[:song.artist.index(" Featuring")]  if " Featuring" in song.artist else song.artist) for song in chart])

# Assign "hit" feature in the DataFrame
songs_df["hit"] = songs_df.apply(lambda row: 1 if (row["name"], row["artist"]) in hit_songs else 0, axis=1)

songs_df

from google.colab import drive
drive.mount('/content/drive')

songs_df.to_csv('SpotifyAPI_country15-16.csv')
# !cp SpotifyAPI_country15-16.csv "drive/My Drive/Spotify/"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
song_data = []


for i in range(0,1000,50):
  query = "year:2014-2015 genre:country"
  results = sp.search(q=query, type="track", limit=50, offset=i)
  tracks = results["tracks"]["items"]
  for track in tracks:
    name = track["name"][:track["name"].index(' [with')] if ' [with' in track["name"] else track["name"]
    name = name[:name.index(' [feat')] if ' [feat' in name else name
    name = name[:name.index(' (with')] if ' (with' in name else name
    name = name[:name.index(' (feat')] if ' (feat' in name else name
    artist = track["artists"][0]["name"]
    features = sp.audio_features(track["id"])[0]
    song_data += [{
        "name": name.upper(),
        "artist": artist.upper(),
        "danceability": features["danceability"],
        "energy": features["energy"],
        "key": features["key"],
        "loudness": features["loudness"],
        "mode": features["mode"],
        "speechiness": features["speechiness"],
        "acousticness": features["acousticness"],
        "instrumentalness": features["instrumentalness"],
        "liveness": features["liveness"],
        "valence": features["valence"],
        "tempo": features["tempo"],
        "duration_ms": features["duration_ms"]
    }]

songs_df = pd.DataFrame(song_data)

start_date = datetime.date(2014, 1, 1)
end_date = datetime.date(2015, 12, 31)

current_date = start_date
hit_songs = set()

while current_date <= end_date:
    chart = billboard.ChartData("country-songs", date=current_date)
    for song in chart:
      title = song.title
      artist = song.artist[:song.artist.index(" Featuring")]  if " Featuring" in song.artist else song.artist
      artist = artist[:artist.index(" &")]  if " &" in artist else artist
      artist = artist[:artist.index(",")]  if "," in artist else artist
      hit_songs.update([(title.upper(), artist.upper())])

    # print(current_date, hit_songs)
    # hit_songs.update([(song.title, song.artist[:song.artist.index(" Featuring")]  if " Featuring" in song.artist else song.artist) for song in chart])
    current_date += datetime.timedelta(weeks=1)
    # print(current_date, [(song.title, song.artist[:song.artist.index(" Featuring")]  if " Featuring" in song.artist else song.artist) for song in chart])

# Assign "hit" feature in the DataFrame
songs_df["hit"] = songs_df.apply(lambda row: 1 if (row["name"], row["artist"]) in hit_songs else 0, axis=1)

songs_df

from google.colab import drive
drive.mount('/content/drive')

songs_df.to_csv('SpotifyAPI_country14-15.csv')
# !cp SpotifyAPI_country14-15.csv "drive/My Drive/Spotify/"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
song_data = []


for i in range(0,1000,50):
  query = "year:2013-2014 genre:country"
  results = sp.search(q=query, type="track", limit=50, offset=i)
  tracks = results["tracks"]["items"]
  for track in tracks:
    name = track["name"][:track["name"].index(' [with')] if ' [with' in track["name"] else track["name"]
    name = name[:name.index(' [feat')] if ' [feat' in name else name
    name = name[:name.index(' (with')] if ' (with' in name else name
    name = name[:name.index(' (feat')] if ' (feat' in name else name
    artist = track["artists"][0]["name"]
    features = sp.audio_features(track["id"])[0]
    song_data += [{
        "name": name.upper(),
        "artist": artist.upper(),
        "danceability": features["danceability"],
        "energy": features["energy"],
        "key": features["key"],
        "loudness": features["loudness"],
        "mode": features["mode"],
        "speechiness": features["speechiness"],
        "acousticness": features["acousticness"],
        "instrumentalness": features["instrumentalness"],
        "liveness": features["liveness"],
        "valence": features["valence"],
        "tempo": features["tempo"],
        "duration_ms": features["duration_ms"]
    }]

songs_df = pd.DataFrame(song_data)

start_date = datetime.date(2013, 1, 1)
end_date = datetime.date(2014, 12, 31)

current_date = start_date
hit_songs = set()

while current_date <= end_date:
    chart = billboard.ChartData("country-songs", date=current_date)
    for song in chart:
      title = song.title
      artist = song.artist[:song.artist.index(" Featuring")]  if " Featuring" in song.artist else song.artist
      artist = artist[:artist.index(" &")]  if " &" in artist else artist
      artist = artist[:artist.index(",")]  if "," in artist else artist
      hit_songs.update([(title.upper(), artist.upper())])

    # print(current_date, hit_songs)
    # hit_songs.update([(song.title, song.artist[:song.artist.index(" Featuring")]  if " Featuring" in song.artist else song.artist) for song in chart])
    current_date += datetime.timedelta(weeks=1)
    # print(current_date, [(song.title, song.artist[:song.artist.index(" Featuring")]  if " Featuring" in song.artist else song.artist) for song in chart])

# Assign "hit" feature in the DataFrame
songs_df["hit"] = songs_df.apply(lambda row: 1 if (row["name"], row["artist"]) in hit_songs else 0, axis=1)

songs_df

from google.colab import drive
drive.mount('/content/drive')

songs_df.to_csv('SpotifyAPI_country13-14.csv')
# !cp SpotifyAPI_country13-14.csv "drive/My Drive/Spotify/"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
song_data = []


for i in range(0,1000,50):
  query = "year:2012-2013 genre:country"
  results = sp.search(q=query, type="track", limit=50, offset=i)
  tracks = results["tracks"]["items"]
  for track in tracks:
    name = track["name"][:track["name"].index(' [with')] if ' [with' in track["name"] else track["name"]
    name = name[:name.index(' [feat')] if ' [feat' in name else name
    name = name[:name.index(' (with')] if ' (with' in name else name
    name = name[:name.index(' (feat')] if ' (feat' in name else name
    artist = track["artists"][0]["name"]
    features = sp.audio_features(track["id"])[0]
    song_data += [{
        "name": name.upper(),
        "artist": artist.upper(),
        "danceability": features["danceability"],
        "energy": features["energy"],
        "key": features["key"],
        "loudness": features["loudness"],
        "mode": features["mode"],
        "speechiness": features["speechiness"],
        "acousticness": features["acousticness"],
        "instrumentalness": features["instrumentalness"],
        "liveness": features["liveness"],
        "valence": features["valence"],
        "tempo": features["tempo"],
        "duration_ms": features["duration_ms"]
    }]

songs_df = pd.DataFrame(song_data)

start_date = datetime.date(2012, 1, 1)
end_date = datetime.date(2013, 12, 31)

current_date = start_date
hit_songs = set()

while current_date <= end_date:
    chart = billboard.ChartData("country-songs", date=current_date)
    for song in chart:
      title = song.title
      artist = song.artist[:song.artist.index(" Featuring")]  if " Featuring" in song.artist else song.artist
      artist = artist[:artist.index(" &")]  if " &" in artist else artist
      artist = artist[:artist.index(",")]  if "," in artist else artist
      hit_songs.update([(title.upper(), artist.upper())])

    # print(current_date, hit_songs)
    # hit_songs.update([(song.title, song.artist[:song.artist.index(" Featuring")]  if " Featuring" in song.artist else song.artist) for song in chart])
    current_date += datetime.timedelta(weeks=1)
    # print(current_date, [(song.title, song.artist[:song.artist.index(" Featuring")]  if " Featuring" in song.artist else song.artist) for song in chart])

# Assign "hit" feature in the DataFrame
songs_df["hit"] = songs_df.apply(lambda row: 1 if (row["name"], row["artist"]) in hit_songs else 0, axis=1)

songs_df

from google.colab import drive
drive.mount('/content/drive')

songs_df.to_csv('SpotifyAPI_country12-13.csv')
# !cp SpotifyAPI_country12-13.csv "drive/My Drive/Spotify/"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
